# %% [markdown]
# <a href="https://colab.research.google.com/github/isomjd-code/latin-courthand-correction/blob/main/latin_case_extractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================================================================
#        Legal Case Extractor for Transkribus PAGE XML (Corrected)
# ==============================================================================
#
# DESCRIPTION:
# This script, designed for Google Colab, processes a single page from a
# Transkribus document containing medieval legal records. It performs the
# following actions:
#
# 1.  Downloads the specified page's PAGE XML from Transkribus.
# 2.  Uses the Anthropic Claude 3.7 Sonnet model to intelligently segment the
#     transcribed text into individual legal cases.
# 3.  For each case, it uses Claude again to:
#     a. Extract key metadata (plaintiffs, defendants, plea type, etc.).
#     b. Expand the abbreviated Latin transcription into full Latin.
#     c. Translate the expanded Latin into modern English.
# 4.  Formats the final, structured data as JSON, Wiki Markup, or Markdown,
#     as specified by the user.
#
# HOW TO USE IN GOOGLE COLAB:
# 1.  In the left sidebar, click the key icon (🔑) and create secrets for:
#     - TRANKRIBUS_USER
#     - TRANKRIBUS_PASSWORD
#     - ANTHROPIC_API_KEY
# 2.  Paste this entire script into a single cell in a new Colab notebook.
# 3.  Fill in the document details in the "USER CONFIGURATION" section below.
# 4.  Run the cell.
#
# ==============================================================================

# --- Step 0: Install Dependencies (only runs if in a Colab-like environment) ---
try:
    import google.colab
    print("Installing required libraries for Google Colab...")
    # Use -q for a quieter installation
    # !pip install -q anthropic lxml requests
    print("Installation complete.")
except ImportError:
    print("Not running in Google Colab. Assuming libraries are already installed.")

# --- Library Imports ---
import os
import requests
import xml.etree.ElementTree as ET
import json
import anthropic
import time
import re
from typing import List, Dict, Any, Optional, Tuple

# Import userdata for secrets management in Colab
try:
    from google.colab import userdata
except ImportError:
    # Define a dummy class if not in Colab for local testing
    class UserData:
        def get(self, key):
            return os.environ.get(key)
    userdata = UserData()


# ==============================================================================
#                           1. USER CONFIGURATION
# ==============================================================================
# --- Transkribus Credentials (from Colab Secrets) ---
# Ensure you have set these secrets in your Colab environment (left sidebar, key icon)
TRANKRIBUS_USERNAME = userdata.get('TRANKRIBUS_USER')
TRANKRIBUS_PASSWORD = userdata.get('TRANKRIBUS_PASSWORD')
ANTHROPIC_API_KEY = userdata.get('anthropic_key')

# --- Document to Process ---
# Using the document details from your error log
COLLECTION_ID = 2093054  # <<< --- YOUR COLLECTION ID --- >>>
DOCUMENT_ID = 9343917  # <<< --- THE SPECIFIC DOCUMENT ID YOU WANT TO PROCESS --- >>>

# --- Output Configuration ---
# Choose your desired output format: 'json', 'wiki', or 'markdown'
OUTPUT_FORMAT = 'wiki'  # <<< --- SET YOUR DESIRED OUTPUT FORMAT HERE --- >>>

# --- LLM Configuration ---
ANTHROPIC_MODEL_NAME = "claude-3-7-sonnet-20250219" # Use the latest powerful model
LLM_TEMPERATURE = 0.1      # Low temperature for deterministic, structured output

# --- File/Directory Configuration ---
TEMP_XML_FILENAME = "downloaded_page.xml" # Temporary file to store downloaded XML.


# ==============================================================================
#                       2. SYSTEM PROMPTS FOR THE LLM
# ==============================================================================

# This prompt is used to split the full page text into individual cases.
CASE_SEGMENTATION_PROMPT = """
You are an expert archivist specializing in the English Court of Common Pleas records. Your task is to segment a full page of transcribed text into individual legal cases.

A new case typically begins with a marginal note like 'Westm'', 'Resum'', or a similar term, or it starts with a new plaintiff's name followed by a phrase like 'optulit se' or 'per attornatum suum'.

You will be given a JSON object where keys are line numbers and values are the transcribed text for that line.

Your task is to return a JSON list of objects. Each object in the list represents one case and must have two keys: 'start_line' and 'end_line', corresponding to the line numbers of that case.

Example Input:
{
  "1": "Westm'",
  "2": "Hugo Brmetson p' attorn' suu' optulit se...",
  "3": "reddit ei quadraginta solidos...",
  "4": "modo mand' q'd nichil h'ent...",
  "5": "xv dies",
  "6": "Westm'",
  "7": "Iosephus de menburu' p'sona ecl'ie...",
  "8": "q'd reddat ei sexmarcas..."
}

Example Output:
[
  {
    "start_line": 1,
    "end_line": 5
  },
  {
    "start_line": 6,
    "end_line": 8
  }
]

Now, analyze the provided text and produce the segmentation list. Output ONLY the valid JSON list and nothing else.
"""

# This prompt processes a single case to extract all required information.
CASE_PROCESSING_PROMPT = """
You are an expert in medieval Latin legal documents, a paleographer, and a historian. You will be given the abbreviated Latin text of a single legal case from the English Court of Common Pleas.

Your task is to produce a single, valid JSON object with four keys:

1.  `metadata`: An object containing extracted information about the case. It should include:
    *   `plaintiffs`: A list of plaintiff names.
    *   `defendants`: A list of defendant names.
    *   `plea_type`: A concise description of the plea (e.g., "Debt", "Trespass", "Account", "Detinue of chattels").
    *   `county`: The county or location mentioned, if any.
    *   `values_mentioned`: A list of any monetary values or damages (e.g., "40 solidos", "100 solidorum").

2.  `abbreviated_latin`: The original, unmodified abbreviated Latin text that was provided as input.

3.  `expanded_latin`: A full expansion of the abbreviated Latin. Follow standard paleographic conventions:
    *   `p' attorn' suu'` -> `per attornatum suum`
    *   `q'd` -> `quod`
    *   `&c` -> `et cetera`
    *   `d'ni R'` -> `domini Regis`
    *   `Will'm` -> `Willelmum`
    *   `uic'` -> `uicecomes`
    *   `pl'ito` -> `placito`
    *   Always use 'u' (not 'v') and 'i' (not 'j').

4.  `english_translation`: A clear, modern English translation of the fully expanded Latin text.

Ensure your entire output is a single, valid JSON object and nothing else.
"""

# ==============================================================================
#                       3. HELPER & CORE FUNCTIONS
# ==============================================================================

def get_transkribus_session() -> requests.Session:
    """Authenticates with Transkribus and returns a session object."""
    if not TRANKRIBUS_USERNAME or not TRANKRIBUS_PASSWORD:
        raise ValueError("Transkribus username and password must be provided via Colab Secrets.")

    print(f"Authenticating with Transkribus as user: {TRANKRIBUS_USERNAME}...")
    login_url = "https://transkribus.eu/TrpServer/rest/auth/login"
    session = requests.Session()
    try:
        response = session.post(login_url, data={'user': TRANKRIBUS_USERNAME, 'pw': TRANKRIBUS_PASSWORD})
        response.raise_for_status()
        if '<sessionId>' in response.text and 'JSESSIONID' in session.cookies:
            print("✅ Transkribus authentication successful.")
            return session
        else:
            raise ConnectionRefusedError(f"Transkribus login failed. Response: {response.text[:500]}")
    except requests.exceptions.RequestException as e:
        print(f"FATAL: Network error during Transkribus authentication: {e}")
        raise

def get_first_page_nr(session: requests.Session, coll_id: int, doc_id: int) -> int:
    """
    Gets the page number for the first page of a document by parsing JSON.
    This is the corrected function.
    """
    print(f"Getting page details for document {doc_id}...")
    pages_url = f"https://transkribus.eu/TrpServer/rest/collections/{coll_id}/{doc_id}/pages"
    try:
        # The 'pages' endpoint returns JSON, not XML.
        response = session.get(pages_url, params={"page": 0})
        response.raise_for_status()

        # Parse the response as JSON
        data = response.json()

        page_list = []
        # The API can return a list directly or a dict containing a list
        if isinstance(data, list):
            page_list = data
        elif isinstance(data, dict) and 'trpPage' in data:
            page_list = data['trpPage']

        if page_list and len(page_list) > 0:
            first_page_info = page_list[0]
            if 'pageNr' in first_page_info:
                page_nr = int(first_page_info['pageNr'])
                print(f"✅ Found first page number: {page_nr}")
                return page_nr

        # If we get here, something is wrong with the response structure
        raise ValueError("Could not find 'pageNr' in the JSON response.")

    except (requests.exceptions.RequestException, json.JSONDecodeError, ValueError, IndexError) as e:
        # Catch a wider range of potential errors
        print(f"FATAL: Could not get page number for document {doc_id}: {e}")
        # Add a debug print to help the user if it fails again
        if 'response' in locals():
            print(f"DEBUG: Raw response from server was: {response.text[:500]}")
        raise

def download_page_xml(session: requests.Session, coll_id: int, doc_id: int, page_nr: int, output_path: str) -> bool:
    """Downloads the latest PAGE XML for a specific page."""
    print(f"Downloading latest PAGE XML for doc {doc_id}, page {page_nr}...")
    # The /text endpoint gets the latest transcript version
    xml_url = f"https://transkribus.eu/TrpServer/rest/collections/{coll_id}/{doc_id}/{page_nr}/text"
    try:
        response = session.get(xml_url)
        response.raise_for_status()
        with open(output_path, 'wb') as f:
            f.write(response.content)
        print(f"✅ PAGE XML downloaded successfully to {output_path}")
        return True
    except requests.exceptions.RequestException as e:
        print(f"FATAL: Error downloading PAGE XML: {e}")
        raise

def parse_lines_from_xml(xml_path: str) -> Dict[int, str]:
    """Parses PAGE XML to extract an ordered dictionary of line number to text."""
    print(f"Parsing XML file: {xml_path}...")
    try:
        tree = ET.parse(xml_path)
        root = tree.getroot()
        namespace = {'page': 'http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15'}
        lines_text = {}
        line_counter = 1 # Use 1-based indexing for clarity in prompts

        # Find all TextLine elements in reading order
        for text_line in root.findall('.//page:TextLine', namespace):
            text_equiv = text_line.find('page:TextEquiv/page:Unicode', namespace)
            if text_equiv is not None and text_equiv.text:
                lines_text[line_counter] = text_equiv.text.strip()
            else:
                lines_text[line_counter] = "" # Handle empty lines
            line_counter += 1

        print(f"✅ Successfully parsed XML. Found {len(lines_text)} text lines.")
        return lines_text
    except (ET.ParseError, ValueError) as e:
        print(f"FATAL: Error parsing XML file: {e}")
        raise

def call_anthropic_api(client: anthropic.Anthropic, system_prompt: str, user_prompt: str) -> Optional[Dict[str, Any]]:
    """Makes a call to the Anthropic API and returns the parsed JSON response."""
    try:
        message = client.messages.create(
            model=ANTHROPIC_MODEL_NAME,
            max_tokens=4096,
            temperature=LLM_TEMPERATURE,
            system=system_prompt,
            messages=[{"role": "user", "content": user_prompt}]
        )
        response_text = message.content[0].text

        # Clean the response to extract only the JSON part
        json_match = re.search(r'\{.*\}|\[.*\]', response_text, re.DOTALL)
        if not json_match:
            print("    ❌ ERROR: LLM did not return a JSON object or list.")
            print(f"    LLM Raw Response: {response_text}")
            return None

        cleaned_json_text = json_match.group(0)
        return json.loads(cleaned_json_text)

    except anthropic.APIError as e:
        print(f"    ❌ FATAL: Anthropic API Error: {e}")
        raise
    except json.JSONDecodeError:
        print("    ❌ ERROR: Failed to decode JSON from LLM response.")
        print(f"    LLM Raw Response: {response_text}")
        return None
    except Exception as e:
        print(f"    ❌ An unexpected error occurred during the API call: {e}")
        return None

def format_as_json(data: List[Dict]) -> str:
    """Formats the processed data as a JSON string."""
    return json.dumps(data, indent=2)

def format_as_wiki(data: List[Dict]) -> str:
    """Formats the processed data as Wiki Markup."""
    output = []
    for i, case in enumerate(data):
        meta = case.get('metadata', {})
        plaintiffs = ", ".join(meta.get('plaintiffs', ['N/A']))
        defendants = ", ".join(meta.get('defendants', ['N/A']))
        plea = meta.get('plea_type', 'N/A')
        values = ", ".join(meta.get('values_mentioned', ['N/A']))

        output.append(f"== Case {i+1}: {plaintiffs} v. {defendants} ==")
        output.append(f"'''Plea Type:''' {plea}")
        output.append(f"'''Values Mentioned:''' {values}\n")

        output.append('{| class="wikitable"')
        output.append('|+ Case Details')
        output.append('|-')
        output.append('! Abbreviated Latin')
        output.append('! Expanded Latin')
        output.append('! English Translation')
        output.append('|-')
        # Pipe characters in text need to be escaped for wikitables
        abbr = case.get('abbreviated_latin', '').replace('|', '{{!}}')
        expd = case.get('expanded_latin', '').replace('|', '{{!}}')
        eng = case.get('english_translation', '').replace('|', '{{!}}')
        output.append(f"| {abbr}")
        output.append(f"| {expd}")
        output.append(f"| {eng}")
        output.append('|}')
        output.append("\n")
    return "\n".join(output)

def format_as_markdown(data: List[Dict]) -> str:
    """Formats the processed data as Markdown."""
    output = []
    for i, case in enumerate(data):
        meta = case.get('metadata', {})
        plaintiffs = ", ".join(meta.get('plaintiffs', ['N/A']))
        defendants = ", ".join(meta.get('defendants', ['N/A']))
        plea = meta.get('plea_type', 'N/A')
        values = ", ".join(meta.get('values_mentioned', ['N/A']))

        output.append(f"## Case {i+1}: {plaintiffs} v. {defendants}")
        output.append(f"**Plea Type:** {plea}")
        output.append(f"**Values Mentioned:** {values}\n")

        output.append("### Abbreviated Latin")
        output.append(f"> {case.get('abbreviated_latin', '')}\n")

        output.append("### Expanded Latin")
        output.append(f"> {case.get('expanded_latin', '')}\n")

        output.append("### English Translation")
        output.append(f"> {case.get('english_translation', '')}\n")
        output.append("---")
    return "\n".join(output)


# ==============================================================================
#                           4. MAIN EXECUTION WORKFLOW
# ==============================================================================

def main():
    """The main function to run the end-to-end extraction process."""
    start_time = time.time()
    print("==============================================================")
    print("        STARTING TRANSKRIBUS LEGAL CASE EXTRACTOR")
    print(f"        Document ID: {DOCUMENT_ID} in Collection: {COLLECTION_ID}")
    print("==============================================================")

    # --- Initialize API Clients ---
    try:
        if not ANTHROPIC_API_KEY or "YOUR_" in ANTHROPIC_API_KEY:
            raise ValueError("Anthropic API Key is not set. Please configure it in Colab Secrets.")
        if not TRANKRIBUS_USERNAME or "YOUR_" in TRANKRIBUS_USERNAME:
            raise ValueError("Transkribus credentials are not set. Please configure them in Colab Secrets.")

        anthropic_client = anthropic.Anthropic(api_key=ANTHROPIC_API_KEY)
        print("✅ Anthropic client initialized.")

        session = get_transkribus_session()
    except (ValueError, ConnectionRefusedError, requests.exceptions.RequestException) as e:
        print(f"\n--- SCRIPT HALTED: Could not initialize APIs. Error: {e} ---")
        return

    try:
        # --- Step 1: Get Page Info & Download XML ---
        print("\n--- [Step 1/4] Fetching Document Data from Transkribus ---")
        page_nr = get_first_page_nr(session, COLLECTION_ID, DOCUMENT_ID)
        download_page_xml(session, COLLECTION_ID, DOCUMENT_ID, page_nr, TEMP_XML_FILENAME)

        # --- Step 2: Parse XML and Segment into Cases ---
        print("\n--- [Step 2/4] Parsing XML and Segmenting into Cases ---")
        all_lines = parse_lines_from_xml(TEMP_XML_FILENAME)
        if not all_lines:
            print("\n--- SCRIPT HALTED: The downloaded XML contains 0 text lines. ---")
            return

        print("Asking LLM to segment the page into cases...")
        case_segments = call_anthropic_api(
            anthropic_client,
            CASE_SEGMENTATION_PROMPT,
            json.dumps(all_lines, indent=2)
        )

        if not case_segments or not isinstance(case_segments, list):
            print("\n--- SCRIPT HALTED: Could not segment text into cases. ---")
            return

        print(f"✅ LLM identified {len(case_segments)} potential cases.")

        # --- Step 3: Process Each Case ---
        print("\n--- [Step 3/4] Processing Each Case with LLM ---")
        processed_cases = []
        for i, segment in enumerate(case_segments):
            start = segment.get('start_line')
            end = segment.get('end_line')
            print(f"  Processing Case {i+1}/{len(case_segments)} (lines {start}-{end})...")

            if start is None or end is None:
                print(f"    ⚠️ Skipping invalid segment: {segment}")
                continue

            # Collate the text for the current case
            case_lines = [all_lines[j] for j in range(start, end + 1) if j in all_lines]
            case_text = " ".join(case_lines)

            if not case_text.strip():
                print(f"    ⚠️ Skipping empty case.")
                continue

            # Call LLM to process this single case
            case_data = call_anthropic_api(
                anthropic_client,
                CASE_PROCESSING_PROMPT,
                case_text
            )

            if case_data:
                processed_cases.append(case_data)
                print(f"    ✅ Successfully processed Case {i+1}.")
            else:
                print(f"    ❌ Failed to process Case {i+1}.")
            time.sleep(1) # Be polite to the API

        # --- Step 4: Format and Print Output ---
        print(f"\n--- [Step 4/4] Formatting Output as '{OUTPUT_FORMAT.upper()}' ---")
        if not processed_cases:
            print("\n--- No cases were successfully processed. Final output is empty. ---")
            return

        final_output = ""
        if OUTPUT_FORMAT.lower() == 'json':
            final_output = format_as_json(processed_cases)
        elif OUTPUT_FORMAT.lower() == 'wiki':
            final_output = format_as_wiki(processed_cases)
        elif OUTPUT_FORMAT.lower() == 'markdown':
            final_output = format_as_markdown(processed_cases)
        else:
            print(f"  ❌ ERROR: Unknown output format '{OUTPUT_FORMAT}'. Defaulting to JSON.")
            final_output = format_as_json(processed_cases)

        print("\n" + "="*25 + " FINAL OUTPUT " + "="*25 + "\n")
        print(final_output)
        print("\n" + "="*64 + "\n")


    except (ValueError, ConnectionRefusedError, requests.exceptions.RequestException, anthropic.APIError, ET.ParseError, IOError) as e:
        print(f"\n--- SCRIPT HALTED DUE TO A CRITICAL ERROR ---")
        print(f"Error: {e}")
    finally:
        # --- Cleanup ---
        print("--- Cleaning up temporary files... ---")
        if os.path.exists(TEMP_XML_FILENAME):
            os.remove(TEMP_XML_FILENAME)
            print(f"Removed {TEMP_XML_FILENAME}")

        end_time = time.time()
        print("\n==============================================================")
        print("            PROCESS COMPLETE")
        print(f"            Total execution time: {end_time - start_time:.2f} seconds.")
        print("==============================================================")


# --- Execute the main function when the script is run ---
if __name__ == "__main__":
    main()
# Out:
# Installing required libraries for Google Colab...
# Installation complete.
# ==============================================================
#         STARTING TRANSKRIBUS LEGAL CASE EXTRACTOR
#         Document ID: 9343917 in Collection: 2093054
# ==============================================================
# ✅ Anthropic client initialized.
# Authenticating with Transkribus as user: isomjd@gmail.com...
# ✅ Transkribus authentication successful.
#
# --- [Step 1/4] Fetching Document Data from Transkribus ---
# Getting page details for document 9343917...
# ✅ Found first page number: 1
# Downloading latest PAGE XML for doc 9343917, page 1...
# ✅ PAGE XML downloaded successfully to downloaded_page.xml
#
# --- [Step 2/4] Parsing XML and Segmenting into Cases ---
# Parsing XML file: downloaded_page.xml...
# ✅ Successfully parsed XML. Found 60 text lines.
# Asking LLM to segment the page into cases...
# ✅ LLM identified 12 potential cases.
#
# --- [Step 3/4] Processing Each Case with LLM ---
#   Processing Case 1/12 (lines 1-5)...
#     ✅ Successfully processed Case 1.
#   Processing Case 2/12 (lines 6-9)...
#     ✅ Successfully processed Case 2.
#   Processing Case 3/12 (lines 10-10)...
#     ✅ Successfully processed Case 3.
#   Processing Case 4/12 (lines 11-15)...
#     ✅ Successfully processed Case 4.
#   Processing Case 5/12 (lines 16-21)...
#     ✅ Successfully processed Case 5.
#   Processing Case 6/12 (lines 22-30)...
#     ✅ Successfully processed Case 6.
#   Processing Case 7/12 (lines 31-37)...
#     ✅ Successfully processed Case 7.
#   Processing Case 8/12 (lines 39-43)...
#     ✅ Successfully processed Case 8.
#   Processing Case 9/12 (lines 44-50)...
#     ✅ Successfully processed Case 9.
#   Processing Case 10/12 (lines 51-54)...
#     ✅ Successfully processed Case 10.
#   Processing Case 11/12 (lines 55-55)...
#     ✅ Successfully processed Case 11.
#   Processing Case 12/12 (lines 56-60)...
#     ✅ Successfully processed Case 12.
#
# --- [Step 4/4] Formatting Output as 'WIKI' ---
#
# ========================= FINAL OUTPUT =========================
#
# == Case 1: Hugo Brmetson v. Willelmus Cronder de Burgh, Robertus Dokson de Burgh ==
# '''Plea Type:''' Debt
# '''Values Mentioned:''' quadraginta solidos
#
# {| class="wikitable"
# |+ Case Details
# |-
# ! Abbreviated Latin
# ! Expanded Latin
# ! English Translation
# |-
# | Westm' Hugo Brmetson p' attorn' suu' optulit se quarto die u'sus Will'm Cronder de Burgh & Rob'tum Dokson de Burgh de pl'ito q'd ut' p' eor' reddit ei quadraginta solidos quos e debent & iniuste detinent & ip'e non uen't & p'cept' fuit uic' q'd sum' eos &c & uic' modo mand' q'd nichil h'ent &c I'o p'cept' est uic' q'd capiat eos si &c & saluo &c ita q'd ha'eat corpora eor' hic a die s'ce Trinitatis in xv dies
# | Westmonasterium Hugo Brmetson per attornatum suum optulit se quarto die uersus Willelmum Cronder de Burgh et Robertum Dokson de Burgh de placito quod uterque per eorum reddit ei quadraginta solidos quos ei debent et iniuste detinent et ipse non uenerunt et preceptum fuit uicecomiti quod summoneat eos et cetera et uicecomes modo mandauit quod nichil habent et cetera Ideo preceptum est uicecomiti quod capiat eos si et cetera et saluo et cetera ita quod habeat corpora eorum hic a die sancte Trinitatis in quindecim dies
# | Westminster. Hugo Brmetson, through his attorney, presented himself on the fourth day against William Cronder of Burgh and Robert Dokson of Burgh in a plea that each of them render to him forty shillings which they owe him and unjustly detain. And they did not come. And the sheriff was ordered to summon them, etc. And the sheriff now reports that they have nothing, etc. Therefore the sheriff is ordered to arrest them if etc. and safely etc. so that he may have their bodies here fifteen days from the day of Holy Trinity.
# |}
#
#
# == Case 2: Iosephus de Menburu, persona ecclesie de Askeby v. Thomas Willesson de Magnea Askeby ==
# '''Plea Type:''' Debt
# '''Values Mentioned:''' sex marcas
#
# {| class="wikitable"
# |+ Case Details
# |-
# ! Abbreviated Latin
# ! Expanded Latin
# ! English Translation
# |-
# | Westm' Iosephus de menburu' p'sona ecl'ie de Askeby p' attornat' suu' optulit se quarto die u'sus Thomam Willesson de Magnea Askeby de pl'ito q'd reddat ei sexmarcas quas ei debet & iniuste detinet &c & ip'e non uen't & p'cept' fuit uic' q'd sum' eu' &c & uic' mand' q'd nichil h'et &c I'o p'ceptu' est uic' q'd capiat eum si &c & saluo &c ita q'd h'eat corpus eius hic a die s'ce Trinitatis in xv dies &c
# | Westmonasterium Iosephus de menburum persona ecclesie de Askeby per attornatum suum optulit se quarto die uersus Thomam Willesson de Magnea Askeby de placito quod reddat ei sex marcas quas ei debet et iniuste detinet et cetera et ipse non uenit et preceptum fuit uicecomiti quod summoneat eum et cetera et uicecomes mandauit quod nichil habet et cetera Ideo preceptum est uicecomiti quod capiat eum si et cetera et saluo et cetera ita quod habeat corpus eius hic a die sancte Trinitatis in quindecim dies et cetera
# | Westminster. Joseph of Menburum, parson of the church of Askeby, through his attorney, presented himself on the fourth day against Thomas Willesson of Great Askeby in a plea that he render to him six marks which he owes him and unjustly detains, etc. And he [Thomas] has not come. And the sheriff was ordered to summon him, etc. And the sheriff reported that he has nothing, etc. Therefore the sheriff is ordered to arrest him if etc. and safely etc. so that he may have his body here fifteen days from the day of Holy Trinity, etc.
# |}
#
#
# == Case 3: Henricus Ynskyp v. Iohannes Ynskyp de Kyrkeby Ireleth, Robertus Dokson de Kyrkeby Ireleth ==
# '''Plea Type:''' Unspecified plea
# '''Values Mentioned:'''
#
# {| class="wikitable"
# |+ Case Details
# |-
# ! Abbreviated Latin
# ! Expanded Latin
# ! English Translation
# |-
# | Henr' ynskyp p' attorn' suu' op' se iiij° die u'sus Ioh'em ynskyp de Kyrkeby Ireleth & Rob'tum Dokson de Kyrkeby Ireleth de pl'i
# | Henricus Ynskyp per attornatum suum optulit se quarto die uersus Iohannem Ynskyp de Kyrkeby Ireleth et Robertum Dokson de Kyrkeby Ireleth de placito
# | Henry Ynskyp, through his attorney, presented himself on the fourth day against John Ynskyp of Kirkby Ireleth and Robert Dokson of Kirkby Ireleth in a plea
# |}
#
#
# == Case 4: Ricardus Iusgran v. Iohannes Marshall de Kirkebystephan, Willelmus Tarran de Kirkebysterham ==
# '''Plea Type:''' Trespass vi et armis
# '''Values Mentioned:''' sexaginta solidorum (60 shillings)
#
# {| class="wikitable"
# |+ Case Details
# |-
# ! Abbreviated Latin
# ! Expanded Latin
# ! English Translation
# |-
# | Ricardus Iusgran p' attorn' suu' optulit se quarto die u'sus Ioh'em Marshall' de Kirkebystephan & Will'm Tarran de Kirkebysterham de pl'ito quare ui & armis blada & herbam ip'ius Ricardi ad ualenc' sexaginta solidor' apud Hertlay nup' crescenta cu' quibusdam anu'is depasti fuerunt conculcauerunt & consumpserunt & alia enormia &c ad graue dampnu' &c & contra pacem d'ni h' nup' Regis &c & ip'i non uen' & p'cept' fuit uic' q'd attach' eos &c & uic' mand' q'd nichil h'ent &c I'o p'cept' est uic' q'd capiat eos si &c & saluo &c Ita q'd h'eat corpora eor' hic a die s'ce Trinitatis in xv dies &c
# | Ricardus Iusgran per attornatum suum optulit se quarto die uersus Iohannem Marshall de Kirkebystephan et Willelmum Tarran de Kirkebysterham de placito quare ui et armis blada et herbam ipsius Ricardi ad ualenciam sexaginta solidorum apud Hertlay nuper crescenta cum quibusdam animalibus depasti fuerunt conculcauerunt et consumpserunt et alia enormia et cetera ad graue dampnum et cetera et contra pacem domini henrici nuper Regis et cetera et ipsi non uenerunt et preceptum fuit uicecomiti quod attachiaret eos et cetera et uicecomes mandauit quod nichil habent et cetera Ideo preceptum est uicecomiti quod capiat eos si et cetera et saluo et cetera Ita quod habeat corpora eorum hic a die sancte Trinitatis in quindecim dies et cetera
# | Richard Iusgran, through his attorney, presented himself on the fourth day against John Marshall of Kirkbystephen and William Tarran of Kirkbysterham in a plea of why they, with force and arms, grazed, trampled, and consumed with certain animals the crops and grass of the said Richard, recently growing at Hertlay, to the value of sixty shillings, and committed other outrages, etc., to his grave damage, etc., and against the peace of lord Henry, late King, etc. And they have not come, and the sheriff was ordered to attach them, etc., and the sheriff reported that they have nothing, etc. Therefore the sheriff is ordered to arrest them if, etc., and safely, etc., so that he may have their bodies here fifteen days from the day of Holy Trinity, etc.
# |}
#
#
# == Case 5: Thomas de Warthecop v. Thomas delyate, Johannes Andreweson ==
# '''Plea Type:''' Trespass vi et armis
# '''Values Mentioned:''' sexaginta solidorum, quadraginta solidorum
#
# {| class="wikitable"
# |+ Case Details
# |-
# ! Abbreviated Latin
# ! Expanded Latin
# ! English Translation
# |-
# | Thomas de Warthecop' p' attorn' suu' optulit se quarto die u'sus Thomam delyate & Ioh'em Andreweson' de pl'ito quare ui & armis arbores & subboscu' ip'ius Thome de Warthecop' ad ualenc' sexaginta solidor' apud Warthecop' nup' crescent' succiderunt & asportauerunt & blada & herbam sua ad ualenc' quadraginta solidor' ib'dem nup' crescente' cu' quibusdam anu'is depasti fuerunt conculcauerunt & consumpser' & alia enormia &c ad graue dampnu' &c & contra pacem d'ni h' nup' Regis &c Et ip'i non uen' & p'cept' fuit uic' q'd attach' eos &c & uic' mand' q'd nichil h'ent &c I'o p'cept' est uic' q'd capiat eos si &c & saluo &c Ita q'd h'eat corpora eor' hic a die s'ci Mich'is tre septila' &c
# | Thomas de Warthecop per attornatum suum optulit se quarto die uersus Thomam delyate et Iohannem Andreweson de placito quare ui et armis arbores et subboscum ipsius Thome de Warthecop ad ualenciam sexaginta solidorum apud Warthecop nuper crescentes succiderunt et asportauerunt et blada et herbam sua ad ualenciam quadraginta solidorum ibidem nuper crescentem cum quibusdam animalibus depasti fuerunt conculcauerunt et consumpserunt et alia enormia et cetera ad graue dampnum et cetera et contra pacem domini henrici nuper Regis et cetera Et ipsi non uenerunt et preceptum fuit uicecomiti quod attachiat eos et cetera et uicecomes mandauit quod nichil habent et cetera Ideo preceptum est uicecomiti quod capiat eos si et cetera et saluo et cetera Ita quod habeat corpora eorum hic a die sancti Michaelis tres septimanas et cetera
# | Thomas de Warthecop, through his attorney, presented himself on the fourth day against Thomas delyate and John Andreweson in a plea of why they, with force and arms, cut down and carried away trees and underbrush of the said Thomas de Warthecop, recently growing at Warthecop, to the value of sixty shillings, and with certain animals they grazed upon, trampled, and consumed his grain and grass recently growing in the same place to the value of forty shillings, and committed other injuries, etc., to his grave damage, etc., and against the peace of lord Henry, late King, etc. And they have not come, and the sheriff was ordered to attach them, etc., and the sheriff reported that they have nothing, etc. Therefore the sheriff is ordered to arrest them if, etc., and safely, etc., so that he may have their bodies here three weeks from Michaelmas, etc.
# |}
#
#
# == Case 6: Willelmus Sanderson de Eewale v. Robertus de Leuenes de Kirkeby in kendale, Thomas de Aykbonk estud' de Yeland', Thomas Wilson de Bethom ==
# '''Plea Type:''' Debt
# '''Values Mentioned:''' quatuordecim marcas
#
# {| class="wikitable"
# |+ Case Details
# |-
# ! Abbreviated Latin
# ! Expanded Latin
# ! English Translation
# |-
# | Will'mus Sanderson de Eewale p' attorn' suu' optulit se quarto die u'sus Rob'tum de Leuenes de Kirkeby in kendale Thomam de Aykbonk estud' de Yeland' in com' Lancastr' & Thomam Wilson de Bethom de pl'ito q'd quil't eor' reddat ei quatuordecim marcas quas ei debent & iniuste detinent &c & ip'i non uen't & p'cept' fuit uic' q'd cap' eos & uic' modo mand' q'd p'd'cus Rob'tus sum' Est  hic a die s'c'e Trinitatis in xv dies &c & de p'd'cis Thoma & Thoma mand' q'd nichil h'ent cap' ad p'ftm p'u estud'
# | Willelmus Sanderson de Eewale per attornatum suum optulit se quarto die uersus Robertum de Leuenes de Kirkeby in kendale Thomam de Aykbonk estudiantem de Yeland in comitatu Lancastr' et Thomam Wilson de Bethom de placito quod quilibet eorum reddat ei quatuordecim marcas quas ei debent et iniuste detinent et cetera et ipsi non uenerunt et preceptum fuit uicecomiti quod capiat eos et uicecomes modo mandauit quod predictus Robertus summonitus Est hic a die sancte Trinitatis in quindecim dies et cetera et de predictis Thoma et Thoma mandauit quod nichil habent capiatur ad profectum prout estudiantem
# | William Sanderson of Eewale, through his attorney, presented himself on the fourth day against Robert de Levenes of Kirkby in Kendale, Thomas de Aykbonk, student of Yeland in the county of Lancaster, and Thomas Wilson of Bethom, in a plea that each of them should render to him fourteen marks which they owe him and unjustly detain, etc. And they have not come, and the sheriff was ordered to take them, and the sheriff now reports that the aforesaid Robert is summoned to be here fifteen days from the day of Holy Trinity, etc., and concerning the aforesaid Thomas and Thomas, he reports that they have nothing [by which they can be attached], let them be taken according to procedure as a student.
# |}
#
#
# == Case 7: Johannes de Cliburn v. Johannes Stemenson, Johannes Stellyng, Johannes de Melscaby, Johannes Johanson de Stirbland ==
# '''Plea Type:''' Trespass vi et armis
# '''Values Mentioned:''' centum solidorum, sexaginta solidorum
#
# {| class="wikitable"
# |+ Case Details
# |-
# ! Abbreviated Latin
# ! Expanded Latin
# ! English Translation
# |-
# | Ioh'es de Cliburn p' attornat' suu' optulit se quarto die u'sus Ioh'em Stemenson Ioh'em Stellyng Ioh'em de Melscaby & Ioh'em Iohanson de Stirbland' de pl'ito quare ui & armis arbores & subbescium ip'ius Ioh'is de Cliburn' apud Clibburn nup' crescente' suciderunt & in sepali turbaria sua ib'dem foderunt & turbas inde puectas ac arbores & subbescum' p'd'cos ad ualenc' centum solidoru' ceperunt & asporta uerunt & blada & herbam sua ad ualenc' sexaginta solidoru' ib'dem nup' crescent' cum quibusdam auiis depasti fuerunt conculcauerunt & consumpserunt & alia enormia &c ad graue dampnu' &c & contra pacem d'ni R' Regis &c Et ip'i non uen't & p'cept' fuit uic' q'd attach' eos &c Et uic' modo mandat q'd nichil h'ent &c I'o p'cept' est uic' q'd capiat eos si &c & saluo &c ita q'd h'eat corpora eor' hic a die s'ce Trinitatis in xv dies &c
# | Iohannes de Cliburn per attornatum suum optulit se quarto die uersus Iohannem Stemenson Iohannem Stellyng Iohannem de Melscaby et Iohannem Iohanson de Stirbland de placito quare ui et armis arbores et subbescium ipsius Iohannis de Cliburn apud Clibburn nuper crescentem suciderunt et in sepali turbaria sua ibidem foderunt et turbas inde puectas ac arbores et subbescum predictos ad ualenciam centum solidorum ceperunt et asportauerunt et blada et herbam sua ad ualenciam sexaginta solidorum ibidem nuper crescentem cum quibusdam auiis depasti fuerunt conculcauerunt et consumpserunt et alia enormia et cetera ad graue dampnum et cetera et contra pacem domini Regis et cetera. Et ipsi non uenerunt et preceptum fuit uicecomiti quod attachiat eos et cetera. Et uicecomes modo mandat quod nichil habent et cetera. Ideo preceptum est uicecomiti quod capiat eos si et cetera et saluo et cetera ita quod habeat corpora eorum hic a die sancte Trinitatis in quindecim dies et cetera.
# | John de Cliburn, through his attorney, presented himself on the fourth day against John Stemenson, John Stellyng, John de Melscaby, and John Johanson de Stirbland in a plea of why they, with force and arms, cut down trees and underbrush of the said John de Cliburn recently growing at Clibburn, and dug in his separate turbary there, and took and carried away the turfs extracted from there along with the aforesaid trees and underbrush to the value of one hundred shillings, and with certain animals they grazed upon, trampled, and consumed his grain and grass recently growing there to the value of sixty shillings, and committed other enormities, etc., to his grave damage, etc., and against the peace of the lord King, etc. And they have not come, and the sheriff was ordered to attach them, etc. And the sheriff now reports that they have nothing, etc. Therefore the sheriff is ordered to arrest them if, etc., and safely, etc., so that he may have their bodies here fifteen days from the day of Holy Trinity, etc.
# |}
#
#
# == Case 8: Johannes de Sourby v. Thomas de Warthorp de Lambertfate, Johannes de Apdale de Halbok ==
# '''Plea Type:''' Debt
# '''Values Mentioned:''' quadraginta & duas libras, quadraginta solidos
#
# {| class="wikitable"
# |+ Case Details
# |-
# ! Abbreviated Latin
# ! Expanded Latin
# ! English Translation
# |-
# | Ioh'es de Sourby in p'pria p'sona sua optulit se quarto die u'sus Thomam de Warthorp' de Lambertfate de pl'ito q'd reddat ei quadraginta & duas libras & u'sus Ioh'em de Apdale de Halbok de pl'ito q'd reddat ei quadraginta solidos quos ei debent & iniuste detinent &c & ip'i non uen' & p'cept' fuit uic' q'd sum' eos &c & de p'd'co Thoma mand' uic' suum &c Iuidem attach' q'd sit hic a die s'ci Trinitatis in xv dies &c & de p'd'co Ioh'e de Apdalo mand' uic' q'd nichil h'ent &c I'o p'cept' est uic' q'd capiat eum si &c & saluo &c Ita q'd h'eat corpus eius hic ad p'fatum t'minum &c
# | Iohannes de Sourby in propria persona sua optulit se quarto die uersus Thomam de Warthorp de Lambertfate de placito quod reddat ei quadraginta et duas libras et uersus Iohannem de Apdale de Halbok de placito quod reddat ei quadraginta solidos quos ei debent et iniuste detinent et cetera et ipsi non uenerunt et preceptum fuit uicecomiti quod summoneat eos et cetera et de predicto Thoma mandauit uicecomes suum et cetera Iuidem attachiatus quod sit hic a die sancti Trinitatis in quindecim dies et cetera et de predicto Iohanne de Apdalo mandauit uicecomes quod nichil habent et cetera Ideo preceptum est uicecomiti quod capiat eum si et cetera et saluo et cetera Ita quod habeat corpus eius hic ad prefatum terminum et cetera
# | John de Sourby in his own person offered himself on the fourth day against Thomas de Warthorp of Lambertfate in a plea that he render to him forty-two pounds and against John de Apdale of Halbok in a plea that he render to him forty shillings which they owe him and unjustly detain etc. And they have not come. And the sheriff was ordered to summon them etc. And concerning the aforesaid Thomas, the sheriff reported his etc. The same was attached to be here fifteen days from the day of Holy Trinity etc. And concerning the aforesaid John de Apdalo, the sheriff reported that he has nothing etc. Therefore the sheriff is ordered to arrest him if etc. and safely etc. so that he may have his body here at the aforesaid term etc.
# |}
#
#
# == Case 9: Cristoforus de Morceby v. Iohannes Willeson de Elibeurne, Thomas Mercer de Elibbourne, Willelmus Bryswode de Elibborne, Iollandus Lighlope de Clibourne, Thomas Henresson de Clibbourne ==
# '''Plea Type:''' Trespass vi et armis
# '''Values Mentioned:''' centum solidorum
#
# {| class="wikitable"
# |+ Case Details
# |-
# ! Abbreviated Latin
# ! Expanded Latin
# ! English Translation
# |-
# | Resum' Cristoforus de Morceby p' attorn' suu' optulit se quarto die u'sus Ioh'em Willeson de Elibeurne Thomam Mercer de Elibbourne Will'm Bryswode de Elibborne Iollandn' Lighlope de Clibourne & Thomam Henresson de Clibbourne de pl'ito quare ui & armis bona & catalla ip'ius Cristofori ad ualenc' centum solidor' apud Blynsell' inuent' ceperunt & asportauerunt & alia enormia &c ad graue dampnu' &c & contra pacem d'ni h'nup' Regis &c Et ip'i non uen't & p'cept' fuit uic' q'd attach' eos &c & uic' modo mand' q'd nichil h'ent &c I'o p'cept' est uic' q'd capiat eos si &c & saluo &c Ita q'd h'eat corpora eor' hic a die s'ce Trinitatis in xv dies &c ad quem diem uic' non misit br'e I'o sicut prius capiantur q'd sint hic a die s'ci Mich'is in unu' mensem &c
# | Resummonitus Cristoforus de Morceby per attornatum suum optulit se quarto die uersus Iohannem Willeson de Elibeurne Thomam Mercer de Elibbourne Willelmum Bryswode de Elibborne Iollandum Lighlope de Clibourne et Thomam Henresson de Clibbourne de placito quare ui et armis bona et catalla ipsius Cristofori ad ualenciam centum solidorum apud Blynsell inuenta ceperunt et asportauerunt et alia enormia et cetera ad graue dampnum et cetera et contra pacem domini henrici nuper Regis et cetera Et ipsi non uenerunt et preceptum fuit uicecomiti quod attachiat eos et cetera et uicecomes modo mandauit quod nichil habent et cetera Ideo preceptum est uicecomiti quod capiat eos si et cetera et saluo et cetera Ita quod habeat corpora eorum hic a die sancte Trinitatis in quindecim dies et cetera ad quem diem uicecomes non misit breue Ideo sicut prius capiantur quod sint hic a die sancti Michaelis in unum mensem et cetera
# | Christopher de Morceby, having been resummoned, through his attorney offered himself on the fourth day against John Willeson of Elibeurne, Thomas Mercer of Elibbourne, William Bryswode of Elibborne, Iolland Lighlope of Clibourne, and Thomas Henresson of Clibbourne in a plea of why they, with force and arms, took and carried away the goods and chattels of the said Christopher, to the value of one hundred shillings, found at Blynsell, and committed other outrages, etc., to his grave damage, etc., and against the peace of the lord Henry, late King, etc. And they have not come, and the sheriff was ordered to attach them, etc., and the sheriff now reports that they have nothing, etc. Therefore the sheriff is ordered to arrest them if, etc., and safely, etc., so that he may have their bodies here fifteen days from the day of Holy Trinity, etc., on which day the sheriff did not send the writ. Therefore, as before, let them be arrested so that they may be here one month from the day of St. Michael, etc.
# |}
#
#
# == Case 10: Johannes de Sureby v. Hugo de Salkeld, Henricus de Wherton, Johannes de Brakanthorp, Johannes de Manechall ==
# '''Plea Type:''' Debt
# '''Values Mentioned:''' decem marcas, uiginti marcas, decem marcas
#
# {| class="wikitable"
# |+ Case Details
# |-
# ! Abbreviated Latin
# ! Expanded Latin
# ! English Translation
# |-
# | Westm' Ioh'es de Sureby p'pa p'sona sua optulit se quarto die u'sus Hugonem de Salkeld de pl'ito q'd reddat ei decem marcas & u'sus henric' de Wherton' & Ioh'em de Brakanthorp' de pl'ito q'd ut'q' eor' reddat ei uiginti marcas & u'sus Ioh'em de Manechall' de pl'ito q'd reddat ei decem marcas quas ei debent & iniuste detinent &c Et ip'i non uen't & p'ceptum fuit attach' q'd sint hic a die s'ce Trinitatis in xv dies &c
# | Westmonasterium Johannes de Sureby propria persona sua optulit se quarto die uersus Hugonem de Salkeld de placito quod reddat ei decem marcas et uersus henricum de Wherton et Johannem de Brakanthorp de placito quod uterque eorum reddat ei uiginti marcas et uersus Johannem de Manechall de placito quod reddat ei decem marcas quas ei debent et iniuste detinent et cetera Et ipsi non uenerunt et preceptum fuit attachiare quod sint hic a die sancte Trinitatis in quindecim dies et cetera
# | Westminster. Johannes de Sureby in his own proper person offered himself on the fourth day against Hugo de Salkeld in a plea that he render to him ten marks, and against Henry de Wherton and John de Brakanthorp in a plea that each of them render to him twenty marks, and against John de Manechall in a plea that he render to him ten marks which they owe him and unjustly detain, etc. And they have not come, and it was ordered to attach them that they be here fifteen days from the day of Holy Trinity, etc.
# |}
#
#
# == Case 11: Robertus Denyas v. Adam Warener de Kirkby in Kendale, Robertum Lambard de Crosseby Gerard ==
# '''Plea Type:''' Unknown (not specified in text)
# '''Values Mentioned:'''
#
# {| class="wikitable"
# |+ Case Details
# |-
# ! Abbreviated Latin
# ! Expanded Latin
# ! English Translation
# |-
# | Rob'tus Denyas p' attornat' suu' optulit se quarto die u'sus Adam Warener de Kirkby in kendale & Rob'tum Lambard' de Crosseby Gerard'
# | Robertus Denyas per attornatum suum optulit se quarto die uersus Adam Warener de Kirkby in Kendale et Robertum Lambard de Crosseby Gerard
# | Robert Denyas, through his attorney, presented himself on the fourth day against Adam Warener of Kirkby in Kendale and Robert Lambard of Crosseby Gerard.
# |}
#
#
# == Case 12: Robertus v. Adam, Robertus Lambard ==
# '''Plea Type:''' Account
# '''Values Mentioned:'''
#
# {| class="wikitable"
# |+ Case Details
# |-
# ! Abbreviated Latin
# ! Expanded Latin
# ! English Translation
# |-
# | Westm' de pl'ito q'd ut'q' eor' reddat ei ronabilem compotu' suum de tempore quo fuit receptor denarior' ip'ius Rob'ti & ip'i non uen' & p'ceptu' fuit uic' q'd sum' eos &c & de p'd'co Adam mand' uic' sum' &c Iudm attach' q'd sit hic a die s'ce Trinitatis in xv dies &c Et de p'd'co Rob'to Lambard' mand' uic' q'd nichil h'ent &c I'o p'cept' est uic' q'd capiat eos si &c & saluo &c Ita q'd h'eat corpora eius hic ad p'fatum t'minum &c
# | Westmonasterium de placito quod uterque eorum reddat ei ronabilem compotum suum de tempore quo fuit receptor denariorum ipsius Roberti et ipsi non uenerunt et preceptum fuit uicecomiti quod summoneat eos et cetera et de predicto Adam mandauit uicecomes summonitus et cetera Iudicium attachietur quod sit hic a die sancte Trinitatis in quindecim dies et cetera Et de predicto Roberto Lambard mandauit uicecomes quod nichil habent et cetera Ideo preceptum est uicecomiti quod capiat eos si et cetera et saluo et cetera Ita quod habeat corpora eius hic ad prefatum terminum et cetera
# | Westminster. Concerning a plea that each of them render to him a reasonable account for the time when he was a receiver of the money of Robert himself. And they have not come. And the sheriff was ordered that he summon them, etc. And concerning the aforesaid Adam, the sheriff reported that he was summoned, etc. Judgment: let him be attached so that he be here fifteen days from the day of Holy Trinity, etc. And concerning the aforesaid Robert Lambard, the sheriff reported that they have nothing, etc. Therefore the sheriff is ordered that he arrest them if etc., and safely etc., so that he have their bodies here at the aforesaid term, etc.
# |}
#
#
#
# ================================================================
#
# --- Cleaning up temporary files... ---
# Removed downloaded_page.xml
#
# ==============================================================
#             PROCESS COMPLETE
#             Total execution time: 126.00 seconds.
# ==============================================================
